# %%
import pandas as pd
import matplotlib.pyplot as plt


# Make sure to upload 'titanic.csv' to your Colab environment or provide the correct path.
# For example, if you upload it directly, this line should work:
titanic= pd.read_csv("titanic.csv") # Assuming the file is directly uploaded or in the current working directory


titanic.info()

#boş kalan yerler varsa toplar ve bize sayısını bildirir
titanic.isnull().sum()

#bize bu tablodaki indexleri yani kolon isimlerini verir
titanic.columns

#mod medyan avg gibi değerleri renkli bir tabloda gösterir
titanic.describe().style.background_gradient(cmap="Spectral_r")

titanic["Survived"] = titanic["Survived"].map({0: "dead", 1: "survived"})
#titanic.describe().style.background_gradient(cmap="Spectral_r")

# Calculate survival percentages
survival_percentages = titanic["Survived"].value_counts(normalize=True) * 100

# Plotting the bar chart for percentages
survival_percentages.plot(kind="bar")
plt.title("Hayatta Kalma Yüzdesi")
plt.xlabel("Durum")
plt.ylabel("Yüzde (%)")
plt.ylim(0, 100) # Set y-axis limit to 0-100 for percentages
plt.xticks(rotation=0) # Ensure labels are horizontal

# Add percentage labels on top of the bars
for index, value in enumerate(survival_percentages):
    plt.text(index, value + 2, f'{value:.2f}%', ha='center', va='bottom')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3654566812.py in <cell line: 0>()
#       5 # Make sure to upload 'titanic.csv' to your Colab environment or provide the correct path.
#       6 # For example, if you upload it directly, this line should work:
# ----> 7 titanic= pd.read_csv("titanic.csv") # Assuming the file is directly uploaded or in the current working directory
#       8
#       9
#
# ...

# %%
# Display descriptive statistics with a colorful background
display(df.describe().style.background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_be05f_row0_col0, #T_be05f_row0_col1, #T_be05f_row0_col2, #T_be05f_row0_col3, #T_be05f_row0_col4, #T_be05f_row0_col5, #T_be05f_row0_col6, #T_be05f_row0_col7, #T_be05f_row0_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average Work_Productivity_Score for each Occupation
avg_productivity_by_occupation = df.groupby('Occupation')['Work_Productivity_Score'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(12, 7))
sns.barplot(x='Work_Productivity_Score', y='Occupation', hue='Occupation', data=avg_productivity_by_occupation, palette='viridis', legend=False)
plt.title('Mesleğe Göre Ortalama Çalışma Üretkenliği Puanı')
plt.xlabel('Ortalama Çalışma Üretkenliği Puanı')
plt.ylabel('Meslek')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
display(df)
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0          U1   58    Male    Professional     Android                1.3
# 1          U2   25    Male    Professional     Android                1.2
# 2          U3   19    Male         Student         iOS                5.3
# 3          U4   35  Female  Business Owner         iOS                5.8
# 4          U5   33    Male      Freelancer     Android                7.9
# ...       ...  ...     ...             ...         ...                ...
# 49995  U49996   44    Male  Business Owner     Android                5.9
# 49996  U49997   42   Other  Business Owner     Android                2.9
# 49997  U49998   27  Female      Freelancer         iOS                1.4
# 49998  U49999   41  Female  Business Owner         iOS                8.9
# 49999  U50000   46   Other      Freelancer     Android                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# ...

# %%
import pandas as pd

file_path = '/content/Smartphone_Usage_Productivity_Dataset_50000.csv'
df = pd.read_csv(file_path)

print(f"Successfully loaded data from: {file_path}")
display(df.head())
# Out:
# Successfully loaded data from: /content/Smartphone_Usage_Productivity_Dataset_50000.csv
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
# ...

# %%
import pandas as pd

# Calculate average Daily_Phone_Hours and Sleep_Hours for each Gender and Stress_Level
avg_data_by_stress_gender = df.groupby(['Gender', 'Stress_Level'])[['Daily_Phone_Hours', 'Sleep_Hours']].mean().reset_index()

print("Cinsiyet ve Stres Seviyesine Göre Ortalama Günlük Telefon Kullanım Süresi ve Uyku Saatleri Tablosu:")
display(avg_data_by_stress_gender)
# Out:
# Cinsiyet ve Stres Seviyesine Göre Ortalama Günlük Telefon Kullanım Süresi ve Uyku Saatleri Tablosu:
#     Gender  Stress_Level  Daily_Phone_Hours  Sleep_Hours
# 0   Female             1           6.544997     6.467833
# 1   Female             2           6.460590     6.475174
# 2   Female             3           6.493546     6.560848
# 3   Female             4           6.474820     6.470793
# 4   Female             5           6.512323     6.445283
# 5   Female             6           6.474556     6.423314
# 6   Female             7           6.484440     6.518492
# 7   Female             8           6.616367     6.502098
# 8   Female             9           6.563383     6.532466
# 9   Female            10           6.479610     6.519267
# 10    Male             1           6.527421     6.501816
# 11    Male             2           6.404509     6.523400
# 12    Male             3           6.553412     6.510861
# 13    Male             4           6.581527     6.483682
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming avg_data_by_stress_gender DataFrame is already available from the previous step
# avg_data_by_stress_gender = df.groupby(['Gender', 'Stress_Level'])[['Daily_Phone_Hours', 'Sleep_Hours']].mean().reset_index()

plt.figure(figsize=(14, 6))

# Plot for Daily_Phone_Hours
plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
sns.lineplot(x='Stress_Level', y='Daily_Phone_Hours', hue='Gender', data=avg_data_by_stress_gender, marker='o')
plt.title('Cinsiyet ve Stres Seviyesine Göre Ortalama Günlük Telefon Kullanım Süresi')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Ortalama Günlük Telefon Kullanım Süresi (Saat)')
plt.xticks(sorted(avg_data_by_stress_gender['Stress_Level'].unique()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Cinsiyet')

# Plot for Sleep_Hours
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
sns.lineplot(x='Stress_Level', y='Sleep_Hours', hue='Gender', data=avg_data_by_stress_gender, marker='x')
plt.title('Cinsiyet ve Stres Seviyesine Göre Ortalama Uyku Saatleri')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Ortalama Uyku Saati (Saat)')
plt.xticks(sorted(avg_data_by_stress_gender['Stress_Level'].unique()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Cinsiyet')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average Sleep_Hours and Stress_Level for each Age_Group
avg_sleep_stress_by_age = df.groupby('Age_Group', observed=False)[['Sleep_Hours', 'Stress_Level']].mean().reset_index()

plt.figure(figsize=(15, 6))

# Plot for Average Sleep_Hours by Age_Group
plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
sns.barplot(x='Age_Group', y='Sleep_Hours', hue='Age_Group', data=avg_sleep_stress_by_age, palette='viridis', legend=False)
plt.title('Yaş Grubuna Göre Ortalama Uyku Saatleri')
plt.xlabel('Yaş Grubu')
plt.ylabel('Ortalama Uyku Saati (Saat)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Plot for Average Stress_Level by Age_Group
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
sns.barplot(x='Age_Group', y='Stress_Level', hue='Age_Group', data=avg_sleep_stress_by_age, palette='plasma', legend=False)
plt.title('Yaş Grubuna Göre Ortalama Stres Seviyesi')
plt.xlabel('Yaş Grubu')
plt.ylabel('Ortalama Stres Seviyesi')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average Sleep_Hours and Stress_Level for each Device_Type
avg_sleep_stress_by_device = df.groupby('Device_Type')[['Sleep_Hours', 'Stress_Level']].mean().reset_index()

plt.figure(figsize=(15, 6))

# Plot for Average Sleep_Hours by Device_Type
plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
sns.barplot(x='Device_Type', y='Sleep_Hours', hue='Device_Type', data=avg_sleep_stress_by_device, palette='coolwarm', legend=False)
plt.title('Cihaz Tipine Göre Ortalama Uyku Saatleri')
plt.xlabel('Cihaz Tipi')
plt.ylabel('Ortalama Uyku Saati (Saat)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Plot for Average Stress_Level by Device_Type
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
sns.barplot(x='Device_Type', y='Stress_Level', hue='Device_Type', data=avg_sleep_stress_by_device, palette='viridis', legend=False)
plt.title('Cihaz Tipine Göre Ortalama Stres Seviyesi')
plt.xlabel('Cihaz Tipi')
plt.ylabel('Ortalama Stres Seviyesi')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lmplot(x='Stress_Level', y='Work_Productivity_Score', data=df, aspect=1.5, palette='viridis', scatter_kws={'alpha':0.3})
plt.title('Stres Seviyesi ve Çalışma Üretkenliği Puanı Arasındaki İlişki')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Çalışma Üretkenliği Puanı')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average Daily_Phone_Hours for each Stress_Level
avg_daily_phone_hours_by_stress = df.groupby('Stress_Level')['Daily_Phone_Hours'].mean().reset_index()

plt.figure(figsize=(12, 7))
sns.barplot(x='Stress_Level', y='Daily_Phone_Hours', hue='Stress_Level', data=avg_daily_phone_hours_by_stress, palette='coolwarm', legend=False)
plt.title('Stres Seviyesine Göre Ortalama Günlük Telefon Kullanım Süresi')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Ortalama Günlük Telefon Kullanım Süresi (Saat)')
plt.xticks(avg_daily_phone_hours_by_stress['Stress_Level']) # Ensure all stress levels are shown on x-axis
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.lmplot(x='Daily_Phone_Hours', y='Work_Productivity_Score', hue='Stress_Level', data=df, aspect=1.5, palette='viridis', scatter_kws={'alpha':0.3})
plt.title('Günlük Telefon Kullanımı ve Çalışma Üretkenliği Puanı Arasındaki İlişki (Stres Seviyesine Göre)')
plt.xlabel('Günlük Telefon Kullanım Süresi (Saat)')
plt.ylabel('Çalışma Üretkenliği Puanı')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Missing values before imputation
print("Eksik değerler (doldurma öncesi):")
display(df.isnull().sum())

# Identify numerical columns with missing values
numerical_cols_with_nan = df.select_dtypes(include=np.number).columns[df.select_dtypes(include=np.number).isnull().any()].tolist()

# Filter the DataFrame to exclude rows with missing 'Gender' for mean calculation
# (though 'Gender' is likely complete based on previous head, this ensures robustness)
df_for_mean_calc = df.dropna(subset=['Gender'])

# Impute missing values in numerical columns with the mean calculated from df_for_mean_calc
for col in numerical_cols_with_nan:
    mean_val = df_for_mean_calc[col].mean()
    df[col] = df[col].fillna(mean_val)

# Missing values after imputation
print("\nEksik değerler (doldurma sonrası):")
display(df.isnull().sum())
# Out:
# Eksik değerler (doldurma öncesi):
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# Age_Group                    0
# dtype: int64
# Eksik değerler (doldurma sonrası):
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average Daily_Phone_Hours and Sleep_Hours for each Stress_Level
avg_data_by_stress = df.groupby('Stress_Level')[['Daily_Phone_Hours', 'Sleep_Hours']].mean().reset_index()

plt.figure(figsize=(12, 7))

# Plot Daily_Phone_Hours vs Stress_Level
sns.lineplot(x='Stress_Level', y='Daily_Phone_Hours', data=avg_data_by_stress, marker='o', label='Ortalama Günlük Telefon Süresi')

# Plot Sleep_Hours vs Stress_Level
sns.lineplot(x='Stress_Level', y='Sleep_Hours', data=avg_data_by_stress, marker='x', label='Ortalama Uyku Saati')

plt.title('Stres Seviyesine Göre Ortalama Günlük Telefon Kullanım Süresi ve Uyku Saatleri')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Ortalama Süre (Saat)')
plt.xticks(avg_data_by_stress['Stress_Level']) # Ensure all stress levels are shown on x-axis
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average Daily_Phone_Hours for each Age_Group
avg_daily_phone_hours_by_age = df.groupby('Age_Group', observed=False)['Daily_Phone_Hours'].mean().reset_index()

plt.figure(figsize=(12, 7))
sns.barplot(x='Age_Group', y='Daily_Phone_Hours', hue='Age_Group', data=avg_daily_phone_hours_by_age, palette='coolwarm', legend=False)
plt.title('Yaş Grubuna Göre Ortalama Günlük Telefon Kullanım Süresi')
plt.xlabel('Yaş Grubu')
plt.ylabel('Ortalama Günlük Telefon Kullanım Süresi (Saat)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Define age bins and labels for categorization
age_bins = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
age_labels = ['15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69']

df['Age_Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Calculate the average Daily_Phone_Hours for each Age_Group and Device_Type
avg_screen_time_by_age_device = df.groupby(['Age_Group', 'Device_Type'], observed=False)['Daily_Phone_Hours'].mean().unstack()

# Plotting the grouped bar chart
avg_screen_time_by_age_device.plot(kind='bar', figsize=(14, 7), width=0.8)
plt.title('Yaş Grubu ve Cihaz Tipine Göre Ortalama Günlük Telefon Kullanım Süresi')
plt.xlabel('Yaş Grubu')
plt.ylabel('Ortalama Günlük Telefon Kullanım Süresi (Saat)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Cihaz Tipi')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=15, kde=True, color='skyblue')
plt.title('Yaş Dağılımı Histogramı')
plt.xlabel('Yaş')
plt.ylabel('Frekans')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the average Work_Productivity_Score for each Device_Type
avg_productivity_by_device = df.groupby('Device_Type')['Work_Productivity_Score'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Device_Type', y='Work_Productivity_Score', hue='Device_Type', data=avg_productivity_by_device, palette='pastel', legend=False)
plt.title('Cihaz Tipine Göre Ortalama Çalışma Üretkenliği Puanı')
plt.xlabel('Cihaz Tipi')
plt.ylabel('Ortalama Çalışma Üretkenliği Puanı')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Analyze the 'Smartphone_Usage_Productivity_Dataset_50000.csv' dataset by performing the following actions:
# 1. Display the entire dataset as a table.
# 2. Show descriptive statistics for numerical columns in a colored table.
# 3. Generate a bar chart showing average 'Work Productivity Score' by 'Occupation'.
# 4. Generate a bar chart showing average 'Work Productivity Score' by 'Device Type' (Android, iOS).
# 5. Create a histogram of the 'Age' distribution.
# 6. Create a grouped bar chart comparing average daily phone usage by 'Age Group' and 'Device Type'.
# 7. Create a bar chart showing average daily phone usage for each 'Age Group'.
# 8. Create a line graph comparing average daily phone usage and average 'Sleep Hours' by 'Stress Level'.
# 9. Generate a summary table of average daily phone usage and average 'Sleep Hours' by 'Gender' and 'Stress Level'.
# 10. Create two separate line graphs comparing average daily phone usage and average 'Sleep Hours' by 'Gender' and 'Stress Level'.
# 11. Create two separate bar graphs showing average 'Sleep Hours' and average 'Stress Level' by 'Age Group'.
# 12. Provide a brief summary of all generated tables and charts.

# %% [markdown]
# ## Veri Setinin Tamamını Göster
#
# ### Subtask:
# Yüklenen 'Smartphone_Usage_Productivity_Dataset_50000.csv' veri setinin tamamını tablo olarak göster.

# %% [markdown]
# **Reasoning**:
# The user wants to display the entire DataFrame `df` as a table. The instruction specifically asks to use `display(df)`.

# %%
display(df)
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0          U1   58    Male    Professional     Android                1.3
# 1          U2   25    Male    Professional     Android                1.2
# 2          U3   19    Male         Student         iOS                5.3
# 3          U4   35  Female  Business Owner         iOS                5.8
# 4          U5   33    Male      Freelancer     Android                7.9
# ...       ...  ...     ...             ...         ...                ...
# 49995  U49996   44    Male  Business Owner     Android                5.9
# 49996  U49997   42   Other  Business Owner     Android                2.9
# 49997  U49998   27  Female      Freelancer         iOS                1.4
# 49998  U49999   41  Female  Business Owner         iOS                8.9
# 49999  U50000   46   Other      Freelancer     Android                8.8
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# ...

# %% [markdown]
# ## Açıklayıcı İstatistikler Tablosu
#
# ### Subtask:
# Veri setindeki sayısal sütunların ortalama, medyan, standart sapma gibi açıklayıcı istatistiklerini renkli bir tablo formatında göster.

# %% [markdown]
# **Reasoning**:
# The user wants to display descriptive statistics of numerical columns in a colorful table. I will use `df.describe()` to get the statistics and then apply `style.background_gradient(cmap='viridis')` for the requested colorful output.

# %%
display(df.describe().style.background_gradient(cmap='viridis'))
# Out:
# <style type="text/css">
# #T_fbc10_row0_col0, #T_fbc10_row0_col1, #T_fbc10_row0_col2, #T_fbc10_row0_col3, #T_fbc10_row0_col4, #T_fbc10_row0_col5, #T_fbc10_row0_col6, #T_fbc10_row0_col7, #T_fbc10_row0_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# ...

# %% [markdown]
# # Task
# Summarize all generated tables and charts.

# %% [markdown]
# ## Stres Seviyesine Göre Ekran Süresi ve Uyku Line Grafiği
#
# ### Subtask:
# Stres seviyelerine göre ortalama günlük telefon kullanım süresi ve ortalama uyku saatlerini karşılaştıran bir çizgi grafik oluştur.

# %% [markdown]
# **Reasoning**:
# The user wants to visualize the average daily phone usage and sleep hours against stress levels using a line plot. The code cell `88fcc3e6` already performs this calculation and plotting, so I will execute that cell.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate average Daily_Phone_Hours and Sleep_Hours for each Stress_Level
avg_data_by_stress = df.groupby('Stress_Level')[['Daily_Phone_Hours', 'Sleep_Hours']].mean().reset_index()

plt.figure(figsize=(12, 7))

# Plot Daily_Phone_Hours vs Stress_Level
sns.lineplot(x='Stress_Level', y='Daily_Phone_Hours', data=avg_data_by_stress, marker='o', label='Ortalama Günlük Telefon Süresi')

# Plot Sleep_Hours vs Stress_Level
sns.lineplot(x='Stress_Level', y='Sleep_Hours', data=avg_data_by_stress, marker='x', label='Ortalama Uyku Saati')

plt.title('Stres Seviyesine Göre Ortalama Günlük Telefon Kullanım Süresi ve Uyku Saatleri')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Ortalama Süre (Saat)')
plt.xticks(avg_data_by_stress['Stress_Level']) # Ensure all stress levels are shown on x-axis
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# To create a scatter plot showing the relationship between stress level and work productivity score, separated by gender, please run the following code:
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# plt.figure(figsize=(12, 7))
# sns.lmplot(x='Stress_Level', y='Work_Productivity_Score', hue='Gender', data=df, aspect=1.5, palette='viridis', scatter_kws={'alpha':0.3})
# plt.title('Stres Seviyesi ve Çalışma Üretkenliği Puanı Arasındaki İlişki (Cinsiyete Göre)')
# plt.xlabel('Stres Seviyesi')
# plt.ylabel('Çalışma Üretkenliği Puanı')
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# ```

# %% [markdown]
# ## Stres, Cinsiyet ve Üretkenlik İlişkisi Grafiği
#
# ### Subtask:
# Stres seviyesi ile çalışma üretkenliği puanı arasındaki ilişkiyi, cinsiyete göre ayrıştırarak gösteren bir saçılım grafiği oluştur.

# %% [markdown]
# **Reasoning**:
# The user wants to visualize the relationship between 'Stress_Level' and 'Work_Productivity_Score', disaggregated by 'Gender', using a scatter plot with a regression line. The `seaborn.lmplot` function is suitable for this purpose, and the instructions clearly define the aesthetic and labeling requirements.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lmplot(x='Stress_Level', y='Work_Productivity_Score', hue='Gender', data=df, aspect=1.5, palette='viridis', scatter_kws={'alpha':0.3})
plt.title('Stres Seviyesi ve Çalışma Üretkenliği Puanı Arasındaki İlişki (Cinsiyete Göre)')
plt.xlabel('Stres Seviyesi')
plt.ylabel('Çalışma Üretkenliği Puanı')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Tüm oluşturulan tablo ve grafiklerin kısa bir özetini sun.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   A scatter plot with regression lines was successfully generated to visualize the relationship between stress level and work productivity score.
# *   The plot effectively separated the data by gender, using different hues to distinguish between groups.
# *   The visualization is titled "Stres Seviyesi ve Çalışma Üretkenliği Puanı Arasındaki İlişki (Cinsiyete Göre)" (Relationship Between Stress Level and Work Productivity Score (By Gender)), with appropriate Turkish labels for the axes.
#
# ### Insights or Next Steps
# *   This visualization provides a clear overview of how stress levels might influence work productivity differently across genders, enabling visual inspection of potential trends.
# *   The next step could involve a statistical analysis of the regression lines (slopes, intercepts) for each gender to quantify and compare the impact of stress on productivity.
